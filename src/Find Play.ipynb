# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/plays.csv')

# %%
df['possessionTeam'].unique()
# Out:
# array(['CIN', 'HOU', 'KC', 'BAL', 'DET', 'IND', 'ARI', 'PHI', 'DAL', 'GB',
#        'ATL', 'LV', 'WAS', 'TEN', 'NE', 'LAC', 'SEA', 'CLE', 'JAX', 'TB',
#        'LA', 'MIA', 'CHI', 'NO', 'CAR', 'BUF', 'SF', 'MIN', 'PIT', 'NYJ',
#        'NYG', 'DEN'], dtype=object)

# %%
df = df[df['possessionTeam'] == "NO"]

df.head()
# Out:
#         gameId  playId                                    playDescription  \
# 55  2022091804     699  (2:06) M.Ingram left tackle to NO 44 for 4 yar...
# 68  2022101605    3982  (:48) (No Huddle, Shotgun) A.Dalton pass incom...
# 73  2022102000    1707  (1:30) (No Huddle, Shotgun) A.Dalton scrambles...
# 91  2022101605    1360  (11:23) Prior to the play, an official timeout...
# 94  2022100906    3633  (14:03) A.Kamara left tackle to NO 30 for 7 ya...
#
#     quarter  down  yardsToGo possessionTeam defensiveTeam yardlineSide  \
# 55        1     2          7             NO            TB           NO
# 68        4     1         10             NO           CIN          CIN
# 73        2     2          2             NO           ARI           NO
# 91        2     1         10             NO           CIN          CIN
# 94        4     1         10             NO           SEA           NO
#
#     yardlineNumber  ... yardsGained  homeTeamWinProbabilityAdded  \
# ...

# %%
top_3_yards_gained = df.nlargest(3, 'yardsGained')
top_3_yards_gained.head()
# Out:
#            gameId  playId                                    playDescription  \
# 2553   2022102000    1025  (11:52) (Shotgun) A.Dalton pass short left to ...
# 6355   2022100906    4083  (5:33) (Shotgun) L.Kidd and L.Young reported i...
# 10365  2022091100     546  (6:33) (Shotgun) T.Hill right end ran ob at AT...
#
#        quarter  down  yardsToGo possessionTeam defensiveTeam yardlineSide  \
# 2553         2     3          2             NO           ARI           NO
# 6355         4     3          1             NO           SEA           NO
# 10365        1     3          1             NO           ATL           NO
#
#        yardlineNumber  ... yardsGained  homeTeamWinProbabilityAdded  \
# 2553               33  ...          64                    -0.153425
# 6355               40  ...          60                     0.258605
# 10365              32  ...          57                    -0.103411
#
#        visitorTeamWinProbilityAdded expectedPointsAdded  isDropback  \
# ...

# %%
# Select play here
play = top_3_yards_gained[top_3_yards_gained['gameId'] == 2022100906]
play = top_3_yards_gained[top_3_yards_gained['playId'] == 546]

play.head()
# Out:
#            gameId  playId                                    playDescription  \
# 10365  2022091100     546  (6:33) (Shotgun) T.Hill right end ran ob at AT...
#
#        quarter  down  yardsToGo possessionTeam defensiveTeam yardlineSide  \
# 10365        1     3          1             NO           ATL           NO
#
#        yardlineNumber  ... yardsGained  homeTeamWinProbabilityAdded  \
# 10365              32  ...          57                    -0.103411
#
#        visitorTeamWinProbilityAdded expectedPointsAdded  isDropback  \
# 10365                      0.103411            3.198946       False
#
#        pff_runConceptPrimary  pff_runConceptSecondary  pff_runPassOption  \
# 10365                  POWER             LEAD;QB RUNS                  0
#
#       pff_passCoverage pff_manZone
# 10365        Goal Line       Other
#
# [1 rows x 50 columns]
