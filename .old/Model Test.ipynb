# %%
import numpy as np
import pandas as pd
import tensorflow as tf

# %%
tracking = pd.read_csv('../data/tracking_week_2.csv')

# %%
tracking = tracking[tracking['frameType'].isin(['BEFORE_SNAP','SNAP'])]

features = ['gameId', 'playId','frameId', 'x', 'y', 's', 'a', 'dis', 'o', 'dir']
tracking = tracking[features]
tracking.head()
# Out:
#        gameId  playId  frameId      x      y     s     a   dis       o     dir
# 0  2022091901      64        1  33.45  20.17  1.59  0.52  0.16    3.19  165.91
# 1  2022091901      64        2  33.49  20.02  1.58  0.42  0.16    1.34  166.20
# 2  2022091901      64        3  33.53  19.86  1.58  0.28  0.16  357.20  164.50
# 3  2022091901      64        4  33.58  19.71  1.59  0.26  0.16  353.77  163.67
# 4  2022091901      64        5  33.62  19.56  1.58  0.34  0.16  351.27  162.08

# %%
# select play
selected_tracking = tracking[(tracking['gameId'] == 2022091500) & (tracking['playId'] == 324)].sort_values(by='frameId')
selected_tracking.head()
# Out:
#              gameId  playId  frameId      x      y     s     a   dis       o  \
# 6288683  2022091500     324        1  58.06  29.73  0.47  3.39  0.04   85.41
# 6291403  2022091500     324        1  57.98  30.95  0.00  0.00  0.02  191.41
# 6289873  2022091500     324        1  56.88  30.73  0.32  0.24  0.04  247.45
# 6291743  2022091500     324        1  56.47  29.62  0.09  1.57  0.02   73.79
# 6289533  2022091500     324        1  57.39  29.78  0.70  1.83  0.06   75.01
#
#             dir
# 6288683   87.43
# 6291403   73.96
# 6289873  263.01
# 6291743  334.93
# 6289533   77.08

# %%
vector = selected_tracking[['x', 'y', 's', 'a', 'dis', 'o', 'dir']]
print(vector)
# Out:
#                  x      y     s     a   dis       o     dir
# 6288683  58.060000  29.73  0.47  3.39  0.04   85.41   87.43
# 6291403  57.980000  30.95  0.00  0.00  0.02  191.41   73.96
# 6289873  56.880000  30.73  0.32  0.24  0.04  247.45  263.01
# 6291743  56.470000  29.62  0.09  1.57  0.02   73.79  334.93
# 6289533  57.390000  29.78  0.70  1.83  0.06   75.01   77.08
# ...            ...    ...   ...   ...   ...     ...     ...
# 6290671  64.870000  41.71  1.66  2.72  0.15  230.06   48.75
# 6291521  60.350000  32.97  0.03  0.56  0.01   77.64  261.15
# 6289651  60.790000  36.88  0.00  0.00  0.00  117.85  107.26
# 6292371  68.100000  15.19  0.30  0.25  0.03  290.41  155.51
# 6292541  61.240002  29.77  5.74  0.30  0.59     NaN     NaN
#
# [2737 rows x 7 columns]

# %%
model = tf.keras.models.load_model('../src/model.h5')

def predict_row(row):
    input_vector = row.values.reshape(1, -1) 
    output_vector = model.predict(input_vector)
    return output_vector.flatten()

# Apply the function to each row
output_vectors = vector.apply(predict_row, axis=1)
# Out:
# ...
# 1/1 [==============================] - 0s 16ms/step
# ...
# ...
# 1/1 [==============================] - 0s 16ms/step
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File c:\Users\zachg\anaconda3\envs\torch\lib\site-packages\pandas\core\internals\construction.py:939, in _finalize_columns_and_data(content, columns, dtype)
#     938 try:
# --> 939     columns = _validate_or_indexify_columns(contents, columns)
#     940 except AssertionError as err:
#     941     # GH#26429 do not raise user-facing AssertionError
#
# File c:\Users\zachg\anaconda3\envs\torch\lib\site-packages\pandas\core\internals\construction.py:986, in _validate_or_indexify_columns(content, columns)
#     984 if not is_mi_list and len(columns) != len(content):  # pragma: no cover
#     985     # caller's responsibility to check for this...
# --> 986     raise AssertionError(
# ...

# %%
# Convert the result to a DataFrame (if needed)
output_df = pd.DataFrame(output_vectors.tolist(), columns=['Output_1', 'Output_2', 'Output_3', 'Output_4'])  # Use actual output dimensions

# %%
frames = selected_tracking['frameId'].values

# %%
merged_df.to_csv('../data/merged_df.csv', index=False)
